# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# ## Dataset:
# >A dataset is a specific instance of data that is utilised for analysis or the construction of a model at any given time. Datasets can take many different forms, including numerical data, categorical data, text data, image data, voice data, and video data.
#
# ## Data wrangling:
# >Data gathering, data importing, data cleaning, data structuring, string processing, HTML parsing, handling dates and times, handling missing data, and text mining are just a few of the activities that make up the data wrangling process, which is a key phase in the preprocessing of data.

# %% [markdown]
# ## Data gathering:
# >The web (web scarping), j-son files, html files, relational databases, and other types of flat files are just a few of the sources from which data is compiled (txt,tsv and csv)
#
# >1. Pandas was used to import the Twitter Archive Enhanced file. It's a csv file known as the hand on file that Udacity has provided and was downloaded from the server.

# %% [markdown]
# >2.Image Prediction I was redirected to the URL provided by the Udacity Downloader, where I saved the tab-separated value (tsv), loaded it on Pandas, and then used (pd.read csv) and (sep='t') to ensure that the data was neatly ordered in a dataframe.

# %% [markdown]
# >3. For my investigation, I used a JSON file that I had acquired from the Udacity website.

# %% [markdown]
# ### Assessing Data
# analysing the data to find any irregularities and any outliers with the goal of creating a clean, high-quality data set that can support analysis.
#
# Assessment Type
# 1. Quality evaluation
# 2. Programatic evaluation
#
# We move to exploratory analysis of the data after the quality and programmatic assessment to produce insights that include
#
# Descriptive analysis: Using a description analytical approach, it was possible to explain what had occurred by highlighting pertinent data. The describe () function is used to produce descriptive statistics that, removing missing values, describe the central tendency, dispersion, and shape of the distribution of a dataset.

# %% [markdown]
# __As a result of my data wrangling, I was able to obtain the following insights__

# %% [markdown]
# 1. In the sample, Charlie was the most widely used dog name.
# ![Capture.JPG](attachment:Capture.JPG)

# %% [markdown]
# 2. The month of December has the most retweets, and the month of July has the most favourites
# ![Capture1a.JPG](attachment:Capture1a.JPG)

# %% [markdown]
# 3. Favorite count and Retweet count are positively correlated.
# ![Capture12n.JPG](attachment:Capture12n.JPG)
